# %%
import pandas as pd 
import numpy as np 

df = pd.read_csv('../data/Cleaned_Data.csv')
df
# Out:
#        Unnamed: 0      ID  Survive  Gender  Smoke      Diabetes  Age  \
# 0               0  TIG1GE        0       1      1        Normal   50
# 1               1  VXUCV9        1       1      0        Normal   75
# 2               2  AFH4F1        1       0      0  Pre-diabetes   80
# 3               4  6CVBRT        0       0      0        Normal   70
# 4               5  5JAQ9G        1       1      0        Normal   55
# ...           ...     ...      ...     ...    ...           ...  ...
# 13634       14992  F1K6V7        0       1      0      Diabetes   68
# 13635       14996  3BK9WM        1       1      1        Normal   62
# 13636       14997  01ZP6F        0       0      0        Normal   61
# 13637       14998  JMSGEG        0       1      0        Normal   77
# 13638       14999  16DJV7        1       1      0        Normal   45
#
#       Ejection Fraction  Sodium  Creatinine  Pletelets  \
# 0                   Low     141         0.7   266000.0
# ...
